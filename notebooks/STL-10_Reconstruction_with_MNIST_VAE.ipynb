# %% [markdown]
# <div align="center" style="font-size:24px;"><b>End-to-End &beta;-Variational Autoencoder (VAE) for SVHN-Normal Dataset</b></div>

# %% [markdown]
# This notebook presents a comprehensive analysis and implementation of a $\beta$-Variational Autoencoder (VAE) using the SVHN-Normal dataset in the Keras framework. Building upon our previous work with the MNIST dataset, this version extends our exploration to a more complex and diverse dataset that includes The Street View House Numbers dataset (SVHN) contains 32x32 cropped images of house numbers obtained from Google Street View. Testing my pre-trained MNIST model on the SVHN (Street View House Numbers) dataset is an interesting challenge due to the differences in image format (32 $\times$ 32 vs. 28 $\times$ 28) and content (Color vs. Grayscale).

# %% [markdown]
# ## Table of Contents
# 1. [Library Imports](#Library-Imports)
# 2. [Loading the SVHN-Normal Dataset](#Loading-the-SVHN-Normal-Dataset)
# 3. [Preprocessing SVHN-Normal Data](#Preprocessing-SVHN-Normal-Data)
# 4. [Loading Pre-Trained Model](#Loading-Pre-Trained-Model)
# 6. [Evaluation Pre-Trained Model](#Evaluation-Pre-Trained-Model)

# %% [markdown]
# <a id="Library Imports"></a>
# ## Library Imports

# %%
#!pip install seaborn
#!pip install tensorflow
#!pip install scikit-image
#!pip install extra-keras-datasets    # refer to: https://github.com/machinecurve/extra_keras_datasets.git
#!pip install opencv-python

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Data Handling and Numerical Libraries
import numpy as np                   
import matplotlib.pyplot as plt             

# Keras - Deep Learning API
import keras                                # High-level neural networks API
from keras import backend as K  

from extra_keras_datasets import stl10     # an image recognition dataset of 10 classes in total (airplane, bird, car, cat, deer, dog, horse, monkey, ship, truck)
import cv2

import random
import sys

from keras.callbacks import (               # Training callbacks
    EarlyStopping,
    ModelCheckpoint,
    ReduceLROnPlateau
)
from keras.models import load_model  
from keras.losses import mse

import tensorflow as tf
# Out:
# /Users/mahdihabibi/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# <a id="Loading the SVHN-Normal Dataset"></a>
# ## Loading the SVHN-Normal Dataset

# %%
# Loading the SVHN-Normal dataset
(x_train, y_train), (x_test, y_test) = stl10.load_data()
# Out:
# INFO:root:Loading dataset = stl-10
# WARNING:root:Please cite the following paper when using or referencing this Extra Keras Dataset:
# WARNING:root:Coates, A., Ng, A., & Lee, H. (2011, June). An analysis of single-layer networks in unsupervised feature learning. In Proceedings of the fourteenth international conference on artificial intelligence and statistics (pp. 215-223).Retrieved from http://cs.stanford.edu/~acoates/papers/coatesleeng_aistats_2011.pdf

# %%
# Visualizing some sample images from the original SVHN dataset (before processing)

def visualize_samples(original_data, sample_indices, figsize=(15, 5)):
    """
    Visualizes a set of original images from the provided dataset.

    :param original_data: The dataset containing the original color images.
    :param sample_indices: A list of indices for the images to be visualized.
    :param figsize: Size of the figure for the plots.
    """
    plt.figure(figsize=figsize)

    for i, img_index in enumerate(sample_indices):
        # Display original color image
        plt.subplot(2, 8, i + 1)
        plt.imshow(original_data[img_index])
        plt.title(f'Original: {img_index}')
        plt.axis('off')


    plt.tight_layout()
    plt.show()

# Number of samples to visualize
num_samples = 16

# Randomly select indices for the samples
random_indices = np.random.choice(len(x_train), num_samples, replace=False)

# Visualize the sampled images
visualize_samples(x_train, random_indices)

# %% [markdown]
# Before diving into the preprocessing steps, it's crucial to understand the format and type of data we're dealing with. Let's examine the data type and shape of the `x_train` dataset:

# %%
print(f"Data Type: {x_train.dtype}")
print(f"Shape: {x_train.shape}")
# Out:
# Data Type: uint8
# Shape: (5000, 96, 96, 3)

# %% [markdown]
# <a id="Preprocessing SVHN-Normal Data"></a>
# ## Preprocessing SVHN-Normal Data

# %% [markdown]
# **Note:**
#
# In general, the image processing for this dataset includes three important steps:
#
# 1- **Converting to Grayscale:** As my model has been pretrained on MNIST as a grayscale dataset, we should convert color images in SVHN dataset to grayscale.
#
# 2- **Resizing:** Resize the images to 28x28 to match the MNIST format.
#
# 3- **Normalization:** Normalizing the images to the range [0, 1] is appropriate and should be done since it matches the preprocessing applied to the MNIST dataset.

# %%
# Function to preprocess the images
def preprocess_images(images):
    processed_images = []
    for img in images:
        # Convert to grayscale
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        # Resize to 28x28
        resized = cv2.resize(gray, (84, 84))
        processed_images.append(resized)
    return np.array(processed_images)

# Preprocess training and testing images
x_train_processed = preprocess_images(x_train)
x_test_processed = preprocess_images(x_test)

# Normalize the images
x_train_processed = x_train_processed.astype('float32') / 255.
x_test_processed = x_test_processed.astype('float32') / 255.

# %%
# Check again the type and shape of elements in x_train_processed after formatting.
print(f"Data Type: {x_train_processed.dtype}")
print(f"Shape: {x_train_processed.shape}")
# Out:
# Data Type: float32
# Shape: (5000, 84, 84)

# %%
def divide_image(image):
    # Each area is 28x28 pixels
    area_size = 28

    # Initialize a dictionary to hold the divided areas
    areas = {}

    # Divide the image into 9 areas (3x3 grid)
    for row in range(3):
        for col in range(3):
            # Calculate the starting point of the current area
            start_x = col * area_size
            start_y = row * area_size

            # Extract the 28x28 area
            area = image[start_y:start_y + area_size, start_x:start_x + area_size]

            # Label the area (e.g., "area11", "area12", etc.)
            label = f"area{row+1}{col+1}"
            areas[label] = area

    return areas

# Apply the function to each image in the dataset
train_areas = [divide_image(img) for img in x_train_processed]
test_areas = [divide_image(img) for img in x_test_processed]

# Now, 'train_areas' and 'test_areas' are lists of dictionaries,
# where each dictionary contains 9 areas of an image labeled as "area11", "area12", etc.

# %%
def extract_area11(areas):
    # Extract 'area11' from each set of areas
    return np.array([areas['area11'] for areas in areas])

# Extract 'area11' from the train and test datasets
x_train_area11 = extract_area11(train_areas)
x_test_area11 = extract_area11(test_areas)

# Check the shape of the extracted areas
print(f"Shape of training data (area11): {x_train_area11.shape}")
print(f"Shape of testing data (area11): {x_test_area11.shape}")
# Out:
# Shape of training data (area11): (5000, 28, 28)
# Shape of testing data (area11): (8000, 28, 28)

# %%
# Retrieving the number of images and their dimensions from the train set
img_num_train = x_train_area11.shape[0]
img_width     = x_train_area11.shape[1]
img_height    = x_train_area11.shape[2]

# Displaying the train set information
print(f"The SVHN-Normal train set contains {img_num_train} images, each with dimensions:"
      f"\n(width x height) = ({img_width} x {img_height}) pixels.")

# Retrieving the number of images from the test set
img_num_test  = x_test_area11.shape[0]

# Displaying the test set information
print(f"The SVHN-Normal test set also contains {img_num_test} images with the same dimensions as the train set.")
# Out:
# The SVHN-Normal train set contains 5000 images, each with dimensions:
# (width x height) = (28 x 28) pixels.
# The SVHN-Normal test set also contains 8000 images with the same dimensions as the train set.

# %% [markdown]
# **Reshaping Image Data for Convolutional Neural Network Input**
#
# **Note**: In machine learning libraries like Keras, images need to be formatted in a specific shape (height, width, channels). The term "channels" refers to the number of color channels in the image. For grayscale images like those in the processed SVHN dataset, there is only one channel. Therefore, we need to reshape our image data to fit this format.

# %%
# Define the number of channels: 1 for grayscale images
num_channels = 1

# Reshape the training and test datasets to include the channel dimension
x_train_processed = x_train_area11.reshape(img_num_train, img_height, img_width, num_channels)
x_test_processed = x_test_area11.reshape(img_num_test, img_height, img_width, num_channels)

# Define the input dimensions for the CNN
input_dimensions = (img_height, img_width, num_channels)

# Display the reshaped dimensions
print(f"Dimensions of each image for the model: (img_height, img_width, num_channels) = {input_dimensions}.")
print(f"Reshaped training data shape: {x_train_processed.shape}")
# Out:
# Dimensions of each image for the model: (img_height, img_width, num_channels) = (28, 28, 1).
# Reshaped training data shape: (5000, 28, 28, 1)

# %%
from sklearn.model_selection import train_test_split

# Split the training data into fine-tuning and validation sets
x_train_fine, x_val, _, _ = train_test_split(
    x_train_processed, 
    np.zeros((x_train_processed.shape[0], )),  # Dummy variable for splitting
    test_size=0.1,  # 10% for validation
    random_state=42  # Seed for reproducibility
)

print(f"Fine-tuning data shape: {x_train_fine.shape}")
print(f"Validation data shape: {x_val.shape}")
# Out:
# Fine-tuning data shape: (4500, 28, 28, 1)
# Validation data shape: (500, 28, 28, 1)

# %% [markdown]
# **Visualizing the processed data to see a few arbitrary images**

# %%
def visualize_samples(data, sample_indices, figsize=(15, 5)):
    """
    Visualizes a set of images from the provided dataset.

    :param data: The dataset containing the images.
    :param sample_indices: A list of indices for the images to be visualized.
    :param figsize: Size of the figure for the plots.
    """
    plt.figure(figsize=figsize)

    for i, img_index in enumerate(sample_indices):
        plt.subplot(2, 8, i + 1)
        plt.imshow(data[img_index][:, :, 0], cmap='gray')
        plt.title(f'Image index: {img_index}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Number of samples to visualize
num_samples = 16

# Randomly select indices for the samples
random_indices = np.random.choice(len(x_train_fine), num_samples, replace=False)

# Visualize the sampled images
visualize_samples(x_train_fine, random_indices)

# %% [markdown]
# **Note:** Be aware that resizing can distort some images, potentially making digits harder for the model to recognize, as seen from some of images above.

# %% [markdown]
# <a id="Model Architecture"></a>
# ## Model Architecture
#
# In this part of my project, I am taking a novel approach by leveraging a pre-trained Variational Autoencoder (VAE) model originally trained on the MNIST dataset. My objective is to adapt this model for the SVHN-Normal dataset. The VAE model comprises three primary components:
#
# 1. **Encoder:** Originally trained on MNIST, the encoder compresses input data into a latent space, capturing essential features. For SVHN-Normal, I will explore how this encoder, pre-trained on digits, performs with a more diverse set of characters.
#
# 2. **Latent Space:** The core of the VAE, where the data is represented in a compressed form. This space is crucial for the generative aspect of the VAE, and I will investigate its effectiveness in representing a broader range of characters.
#
# 3. **Decoder:** This component reconstructs the input data from its latent representation. The decoder, trained on MNIST, will now be tasked with reconstructing SVHN-Normal characters, which will be a test of its generalizability.
#
# By utilizing a pre-trained model, I aim to investigate the transferability of learned features from one dataset to another and the model's ability to adapt to new, more complex data. This approach not only saves computational resources but also provides insights into the flexibility and robustness of our VAE model.

# %% [markdown]
# <a id="Loading Pre-Trained Model"></a>
# ## Loading Pre-Trained Model

# %%
# Path to the saved model
pretrained_model_path = '/Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_model_Autoencoder.keras'

# Load the pre-trained model
pretrained_vae = load_model(pretrained_model_path)

# Display the model's architecture
pretrained_vae.summary()
# Out:
# Model: "full_autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input_layer (Input  [(None, 28, 28, 1)]       0
#  Layer)
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 64)        18496
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 64)        36928
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 64)        36928
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 32)                401440
#
#  decoder_model (Functional)  (None, 28, 28, 1)         543489
#
# =================================================================
# Total params: 1037601 (3.96 MB)
# Trainable params: 1037601 (3.96 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_checkpoint = ModelCheckpoint(
    filepath='/Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras',
    monitor='val_loss',
    save_best_only=True,
    verbose=1,
    mode='min'    # The target, 'val_loss', should be minimized
)

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5,
    verbose=1,
    mode='min'    
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.1,   # Multiplicative factor of learning rate reduction
    patience=5,
    min_lr=0.00001, # Lower bound on the learning rate
    verbose=1
)

callbacks_list = [model_checkpoint, early_stopping, reduce_lr]

# %%
# Compile the model with a smaller learning rate for fine-tuning
fine_tuning_lr = 0.00005  # You can adjust this value as needed
#pretrained_vae.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=fine_tuning_lr), loss='mse')
pretrained_vae.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.00005), loss='mse')

# Fine-tune the model
history = pretrained_vae.fit(
    x_train_fine, x_train_fine,
    epochs=50,  # Adjust as needed
    batch_size=32,  # Adjust as needed
    validation_data=(x_val, x_val),
    callbacks=callbacks_list
)
# Out:
# Epoch 1/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0313
# Epoch 1: val_loss improved from inf to 0.01168, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 39ms/step - loss: 0.0312 - val_loss: 0.0117 - lr: 5.0000e-05
# Epoch 2/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0096
# Epoch 2: val_loss improved from 0.01168 to 0.00837, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 5s 38ms/step - loss: 0.0096 - val_loss: 0.0084 - lr: 5.0000e-05
# Epoch 3/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 3: val_loss improved from 0.00837 to 0.00738, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 39ms/step - loss: 0.0078 - val_loss: 0.0074 - lr: 5.0000e-05
# Epoch 4/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 4: val_loss improved from 0.00738 to 0.00686, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 41ms/step - loss: 0.0071 - val_loss: 0.0069 - lr: 5.0000e-05
# Epoch 5/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 5: val_loss improved from 0.00686 to 0.00653, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 41ms/step - loss: 0.0066 - val_loss: 0.0065 - lr: 5.0000e-05
# Epoch 6/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 6: val_loss improved from 0.00653 to 0.00626, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 42ms/step - loss: 0.0063 - val_loss: 0.0063 - lr: 5.0000e-05
# Epoch 7/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 7: val_loss improved from 0.00626 to 0.00607, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 42ms/step - loss: 0.0061 - val_loss: 0.0061 - lr: 5.0000e-05
# Epoch 8/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 8: val_loss improved from 0.00607 to 0.00592, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 42ms/step - loss: 0.0059 - val_loss: 0.0059 - lr: 5.0000e-05
# Epoch 9/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 9: val_loss improved from 0.00592 to 0.00580, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0058 - val_loss: 0.0058 - lr: 5.0000e-05
# Epoch 10/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 10: val_loss improved from 0.00580 to 0.00570, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0057 - val_loss: 0.0057 - lr: 5.0000e-05
# Epoch 11/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 11: val_loss improved from 0.00570 to 0.00562, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0056 - val_loss: 0.0056 - lr: 5.0000e-05
# Epoch 12/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 12: val_loss improved from 0.00562 to 0.00555, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0055 - val_loss: 0.0056 - lr: 5.0000e-05
# Epoch 13/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 13: val_loss improved from 0.00555 to 0.00551, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 42ms/step - loss: 0.0054 - val_loss: 0.0055 - lr: 5.0000e-05
# Epoch 14/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 14: val_loss improved from 0.00551 to 0.00547, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0054 - val_loss: 0.0055 - lr: 5.0000e-05
# Epoch 15/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 15: val_loss improved from 0.00547 to 0.00542, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 42ms/step - loss: 0.0053 - val_loss: 0.0054 - lr: 5.0000e-05
# Epoch 16/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 16: val_loss improved from 0.00542 to 0.00538, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 42ms/step - loss: 0.0053 - val_loss: 0.0054 - lr: 5.0000e-05
# Epoch 17/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 17: val_loss improved from 0.00538 to 0.00534, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0052 - val_loss: 0.0053 - lr: 5.0000e-05
# Epoch 18/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 18: val_loss improved from 0.00534 to 0.00533, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 42ms/step - loss: 0.0052 - val_loss: 0.0053 - lr: 5.0000e-05
# Epoch 19/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 19: val_loss improved from 0.00533 to 0.00530, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 42ms/step - loss: 0.0052 - val_loss: 0.0053 - lr: 5.0000e-05
# Epoch 20/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 20: val_loss improved from 0.00530 to 0.00528, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 42ms/step - loss: 0.0051 - val_loss: 0.0053 - lr: 5.0000e-05
# Epoch 21/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 21: val_loss improved from 0.00528 to 0.00526, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 42ms/step - loss: 0.0051 - val_loss: 0.0053 - lr: 5.0000e-05
# Epoch 22/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 22: val_loss improved from 0.00526 to 0.00524, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 40ms/step - loss: 0.0051 - val_loss: 0.0052 - lr: 5.0000e-05
# Epoch 23/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 23: val_loss improved from 0.00524 to 0.00522, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 41ms/step - loss: 0.0051 - val_loss: 0.0052 - lr: 5.0000e-05
# Epoch 24/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 24: val_loss improved from 0.00522 to 0.00520, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0050 - val_loss: 0.0052 - lr: 5.0000e-05
# Epoch 25/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 25: val_loss improved from 0.00520 to 0.00518, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0050 - val_loss: 0.0052 - lr: 5.0000e-05
# Epoch 26/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 26: val_loss improved from 0.00518 to 0.00517, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0050 - val_loss: 0.0052 - lr: 5.0000e-05
# Epoch 27/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 27: val_loss improved from 0.00517 to 0.00517, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0050 - val_loss: 0.0052 - lr: 5.0000e-05
# Epoch 28/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 28: val_loss improved from 0.00517 to 0.00514, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0050 - val_loss: 0.0051 - lr: 5.0000e-05
# Epoch 29/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 29: val_loss improved from 0.00514 to 0.00513, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1e-05.
# 141/141 [==============================] - 6s 44ms/step - loss: 0.0049 - val_loss: 0.0051 - lr: 5.0000e-05
# Epoch 30/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 30: val_loss improved from 0.00513 to 0.00511, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0049 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 31/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 31: val_loss improved from 0.00511 to 0.00511, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0049 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 32/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 32: val_loss improved from 0.00511 to 0.00510, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0049 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 33/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 33: val_loss did not improve from 0.00510
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0049 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 34/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 34: val_loss improved from 0.00510 to 0.00510, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0049 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 35/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 35: val_loss did not improve from 0.00510
# 141/141 [==============================] - 6s 42ms/step - loss: 0.0049 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 36/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 36: val_loss improved from 0.00510 to 0.00510, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 41ms/step - loss: 0.0049 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 37/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 37: val_loss improved from 0.00510 to 0.00509, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 41ms/step - loss: 0.0049 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 38/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 38: val_loss improved from 0.00509 to 0.00509, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 41ms/step - loss: 0.0049 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 39/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 39: val_loss improved from 0.00509 to 0.00509, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 42ms/step - loss: 0.0049 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 40/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 40: val_loss improved from 0.00509 to 0.00509, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0049 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 41/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 41: val_loss improved from 0.00509 to 0.00508, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 42ms/step - loss: 0.0048 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 42/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 42: val_loss improved from 0.00508 to 0.00508, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0048 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 43/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 43: val_loss improved from 0.00508 to 0.00508, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0048 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 44/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 44: val_loss improved from 0.00508 to 0.00508, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 44ms/step - loss: 0.0048 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 45/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 45: val_loss improved from 0.00508 to 0.00508, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 44ms/step - loss: 0.0048 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 46/50
# 141/141 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 46: val_loss improved from 0.00508 to 0.00507, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 44ms/step - loss: 0.0048 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 47/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 47: val_loss improved from 0.00507 to 0.00507, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 44ms/step - loss: 0.0048 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 48/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 48: val_loss did not improve from 0.00507
# 141/141 [==============================] - 6s 42ms/step - loss: 0.0048 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 49/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 49: val_loss improved from 0.00507 to 0.00506, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0048 - val_loss: 0.0051 - lr: 1.0000e-05
# Epoch 50/50
# 140/141 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 50: val_loss improved from 0.00506 to 0.00506, saving model to /Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/best_fine_tuned_model_Autoencoder.keras
# 141/141 [==============================] - 6s 43ms/step - loss: 0.0048 - val_loss: 0.0051 - lr: 1.0000e-05

# %% [markdown]
# <a id="Evaluation Pre-Trained Model"></a>
# ## Evaluation Pre-Trained Model

# %% [markdown]
# ### Visualization of original and reconstructed images

# %%
# Path to the saved encoder model
encoder_model_path = '/Volumes/D/GitHub-Portfolio/CompressNetMNIST/models/trained_encoder_model_EMNIST.keras'

# Load the encoder model
encoder_model = load_model(encoder_model_path)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Number of samples to visualize
num_samples = 10

# Randomly select indices for the samples
random_indices = np.random.choice(len(x_test_processed), num_samples, replace=False)

def visualize_comparisons(original_data, model, indices, figsize=(18, 5)):
    """
    Visualizes a comparison of original and reconstructed images.

    :param original_data: The dataset containing the original images.
    :param model: The autoencoder model used for reconstruction.
    :param indices: Indices of the images to be visualized.
    :param figsize: Size of the figure for the plots.
    """
    num_samples = len(indices)
    fig, axes = plt.subplots(2, num_samples, figsize=figsize, constrained_layout=True)
    
    for i, img_index in enumerate(indices):
        # Original Image
        ax = axes[0, i]
        original_img = original_data[img_index].reshape(28, 28)
        ax.imshow(original_img, cmap='gray')
        ax.axis('off')
        ax.set_title(f"Original {img_index}")

        # Reconstructed Image
        ax = axes[1, i]
        reconstructed_img = model.predict(original_data[img_index].reshape(1, 28, 28, 1))
        ax.imshow(reconstructed_img.reshape(28, 28), cmap='gray')
        ax.axis('off')
        ax.set_title(f"Reconstructed {img_index}")

    plt.suptitle("Original vs Reconstructed Images", fontsize=16)
    plt.show()

# Call the visualization function
visualize_comparisons(x_test_processed, pretrained_vae, random_indices)
# Out:
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
